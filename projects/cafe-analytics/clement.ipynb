# %%
# read bigquery data into pandas dataframe
import pandas as pd


df = pd.read_gbq(
    """
    SELECT  *
    FROM `jr-data-training.cafe.cafe-sales`
    --- LIMIT 10
  """,
    project_id="jr-data-training",
    location="australia-southeast1",
)
# Out:
# /var/folders/ms/5jxhpktn4ts_bkyr5s47mbmh0000gn/T/ipykernel_23238/2689036402.py:5: FutureWarning: read_gbq is deprecated and will be removed in a future version. Please use pandas_gbq.read_gbq instead: https://pandas-gbq.readthedocs.io/en/latest/api.html#pandas_gbq.read_gbq
#   df = pd.read_gbq(

# %%
df
# Out:
#        order_id  customer_id                                   ip_addr  \
# 0         11787          517  81741da2cc0e5207bfefbb4ec257b2393d5e13a0
# 1         40606          519  ccf5e36bddfbce1a7de2c04874190a057b30588d
# 2         40488          519  ccf5e36bddfbce1a7de2c04874190a057b30588d
# 3         38252          519  1f8e636af94847a55418d2c03ccf4b1601d10512
# 4         13470          776  d4c84c8e50cf80cc385d669000208e59e304fcca
# ...         ...          ...                                       ...
# 37367     39435          397  e00e759c32c007c65db54afa6282b0865d5d2e00
# 37368     11825          351  fad191a236428187b7b3e6c8351a277acca1fdb5
# 37369      4385            5  e74dfd2931611f12b3d76ed13b9fb5ed4aa17979
# 37370     25364          933  60515b357f6ecfab2df9a9d068553d55eb2b8a49
# 37371     25370          976  5434f21c8acba5f3a07633e770043104033b5c35
#
#              date_created           date_paid  total  status  \
# 0     2021-04-14 05:56:06 2021-04-14 05:56:37   1280       2
# 1     2024-03-05 10:16:40 2024-03-05 10:17:23   1280       2
# 2     2024-03-01 11:40:20 2024-03-01 11:40:58   1280       2
# 3     2023-12-05 08:48:02 2023-12-05 08:49:24   1280       2
# 4     2021-06-20 12:10:17 2021-06-20 12:11:09   1280       2
# ...                   ...                 ...    ...     ...
# 37367 2024-01-26 13:16:02 2024-01-26 13:27:48   4862       2
# 37368 2021-04-15 08:56:50 2021-04-15 08:57:10   5630       2
# 37369 2020-03-20 13:50:17                 NaT  33790      10
# 37370 2022-09-22 12:29:54 2022-09-22 12:30:27   1023       2
# 37371 2022-09-23 07:49:20 2022-09-23 07:51:18   1023       2
#
#                                                    items
# 0      {"cart_size":2,"cart_surcharge":0,"cart_total_...
# 1      {"cart_size":2,"cart_surcharge":0,"cart_total_...
# 2      {"cart_size":2,"cart_surcharge":0,"cart_total_...
# 3      {"cart_size":2,"cart_surcharge":0,"cart_total_...
# 4      {"cart_size":2,"cart_surcharge":0,"cart_total_...
# ...                                                  ...
# 37367  {"cart_size":3,"cart_surcharge":442,"cart_tota...
# 37368  {"cart_size":10,"cart_surcharge":0,"cart_total...
# 37369  {"cart_size":28,"cart_surcharge":0,"cart_total...
# 37370  {"cart_size":2,"cart_surcharge":93,"cart_total...
# 37371  {"cart_size":2,"cart_surcharge":93,"cart_total...
#
# [37372 rows x 8 columns]

# %%
df.count()
# Out:
# order_id        37372
# customer_id     37372
# ip_addr         37372
# date_created    37372
# date_paid       36019
# total           37372
# status          37372
# items           37372
# dtype: int64
