# %%
import pandas as pd
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
pd.set_option('max_colwidth', 1000)

# %%
# Query data from BigQuery into pandas Dataframe
df = pd.read_gbq(
    """
        SELECT *
        FROM `jr-data-training.cafe.cafe-sales`
        LIMIT 10
    """,
    project_id='jr-data-training',
    location='australia-southeast1',
)

# %%
df
# Out:
#    order_id  customer_id                                   ip_addr  \
# 0     11787          517  81741da2cc0e5207bfefbb4ec257b2393d5e13a0
# 1     40606          519  ccf5e36bddfbce1a7de2c04874190a057b30588d
# 2     40488          519  ccf5e36bddfbce1a7de2c04874190a057b30588d
# 3     38252          519  1f8e636af94847a55418d2c03ccf4b1601d10512
# 4     13470          776  d4c84c8e50cf80cc385d669000208e59e304fcca
# 5     33377            9  02d3475e227ed6eeb70daaa61d0ad1d0068dcd08
# 6     32604            9  7a1bb6402b347d07bc52ab100f2b67e7e027a106
# 7     32496            9  3cba56ec1336930ecabe05c12ff862a3ceb12fe3
# 8     32399            9  b756854eea913de767c8ab7df7b7b6329cdf23cc
# 9     32177            9  e82aac3f7a4536d950da2cbe0a0fa3bf389dc16f
#
#          date_created           date_paid  total  status  \
# 0 2021-04-14 05:56:06 2021-04-14 05:56:37   1280       2
# 1 2024-03-05 10:16:40 2024-03-05 10:17:23   1280       2
# 2 2024-03-01 11:40:20 2024-03-01 11:40:58   1280       2
# 3 2023-12-05 08:48:02 2023-12-05 08:49:24   1280       2
# 4 2021-06-20 12:10:17 2021-06-20 12:11:09   1280       2
# 5 2023-07-04 10:30:31 2023-07-04 10:30:48   1280       2
# 6 2023-06-09 08:21:57 2023-06-09 08:22:21   1280       2
# 7 2023-06-05 11:30:51 2023-06-05 11:31:15   1280       2
# 8 2023-06-02 11:08:35 2023-06-02 11:08:56   1280       2
# 9 2023-05-26 11:58:13 2023-05-26 11:58:56   1280       2
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      items
# 0  {"cart_size":2,"cart_surcharge":0,"cart_total_price":1280,"cart_gst":116.3636363636363597606759867630898952484130859375,"cart_surcharge_display":"$0.00","cart_total_price_display":"$12.80","cart_gst_display":"$1.16","cart":[{"name":"Latte","variant_name":"Large","variant_desc":"","variant_image":"images\/coffeecup-latte.png","options":[{"name":"size","value":"LRG","price":430},{"name":"Milk","value":"Soy","price":50},{"name":"Strength","value":"Full","price":0},{"name":"Decaf","value":"Normal","price":0},{"name":"Temp","value":"Normal","price":0},{"name":"Honey","value":"None","price":0},{"name":"Syrup","value":"None","price":0},{"name":"White Sugar","value":"0","price":0},{"name":"Raw Sugar","value":"0","price":0},{"name":"Equal Sugar","value":"0","price":0},{"name":"Extra shot","value":"0","price":0}],"price":480,"category":"Hot Drinks"},{"name":"Toastie","variant_name":"Bacon, Egg and Cheese","variant_desc":"","variant_image":"images\/toastie-baconegg.png","options":[{"name":"si...
# 1  {"cart_size":2,"cart_surcharge":0,"cart_total_price":1280,"cart_gst":116.36363636363636,"cart_surcharge_display":"$0.00","cart_total_price_display":"$12.80","cart_gst_display":"$1.16","cart":[{"name":"Flat White","variant_name":"Extra Large","variant_desc":"","variant_image":"images\/coffee-flatwhite.png","options":[{"name":"size","value":"XLG","price":540},{"name":"Milk","value":"Lactose Free","price":50},{"name":"Strength","value":"Full","price":0},{"name":"Decaf","value":"Normal","price":0},{"name":"Temp","value":"Normal","price":0},{"name":"Honey","value":"None","price":0},{"name":"Syrup","value":"None","price":0},{"name":"White Sugar","value":"0","price":0},{"name":"Raw Sugar","value":"0","price":0},{"name":"Equal Sugar","value":"0","price":0},{"name":"Extra shot","value":"1","price":50}],"unitprice":640,"price":640,"category":"Hot Drinks","quantity":1},{"name":"Latte","variant_name":"Extra Large","variant_desc":"","variant_image":"images\/coffeecup-latte.png","options":[{"nam...
# 2  {"cart_size":2,"cart_surcharge":0,"cart_total_price":1280,"cart_gst":116.36363636363636,"cart_surcharge_display":"$0.00","cart_total_price_display":"$12.80","cart_gst_display":"$1.16","cart":[{"name":"Cappuccino","variant_name":"Extra Large","variant_desc":"","variant_image":"images\/coffeemug-cappuccino.png","options":[{"name":"size","value":"XLG","price":540},{"name":"Milk","value":"Oat Milk","price":100},{"name":"Strength","value":"Full","price":0},{"name":"Decaf","value":"Normal","price":0},{"name":"Temp","value":"Normal","price":0},{"name":"Honey","value":"None","price":0},{"name":"Syrup","value":"None","price":0},{"name":"White Sugar","value":"0","price":0},{"name":"Raw Sugar","value":"0","price":0},{"name":"Equal Sugar","value":"0","price":0},{"name":"Extra shot","value":"0","price":0}],"unitprice":640,"price":640,"category":"Hot Drinks","quantity":1},{"name":"Flat White","variant_name":"Extra Large","variant_desc":"","variant_image":"images\/coffee-flatwhite.png","options":...
# 3  {"cart_size":2,"cart_surcharge":0,"cart_total_price":1280,"cart_gst":116.36363636363636,"cart_surcharge_display":"$0.00","cart_total_price_display":"$12.80","cart_gst_display":"$1.16","cart":[{"name":"Flat White","variant_name":"Extra Large","variant_desc":"","variant_image":"images\/coffee-flatwhite.png","options":[{"name":"size","value":"XLG","price":540},{"name":"Milk","value":"Lactose Free","price":50},{"name":"Strength","value":"Full","price":0},{"name":"Decaf","value":"Normal","price":0},{"name":"Temp","value":"Normal","price":0},{"name":"Honey","value":"None","price":0},{"name":"Syrup","value":"None","price":0},{"name":"White Sugar","value":"0","price":0},{"name":"Raw Sugar","value":"0","price":0},{"name":"Equal Sugar","value":"0","price":0},{"name":"Extra shot","value":"1","price":50}],"unitprice":640,"price":640,"category":"Hot Drinks","quantity":1},{"name":"Latte","variant_name":"Extra Large","variant_desc":"","variant_image":"images\/coffeecup-latte.png","options":[{"nam...
# 4  {"cart_size":2,"cart_surcharge":0,"cart_total_price":1280,"cart_gst":116.36363636363636,"cart_surcharge_display":"$0.00","cart_total_price_display":"$12.80","cart_gst_display":"$1.16","cart":[{"name":"Mocha","variant_name":"Large","variant_desc":"","variant_image":"images\/coffee-cup-mocha.png","options":[{"name":"size","value":"LRG","price":480},{"name":"Milk","value":"Full Cream","price":0},{"name":"Strength","value":"Full","price":0},{"name":"Decaf","value":"Normal","price":0},{"name":"Temp","value":"Normal","price":0},{"name":"Honey","value":"None","price":0},{"name":"Syrup","value":"None","price":0},{"name":"White Sugar","value":"0","price":0},{"name":"Raw Sugar","value":"0","price":0},{"name":"Equal Sugar","value":"0","price":0},{"name":"Extra shot","value":"0","price":0}],"price":480,"category":"Hot Drinks"},{"name":"Thickshake (Syrup)","variant_name":"Large","variant_desc":"","variant_image":"images\/thickshake.png","options":[{"name":"size","value":"LRG","price":800},{"nam...
# 5  {"cart_size":2,"cart_surcharge":0,"cart_total_price":1280,"cart_gst":116.36363636363636,"cart_surcharge_display":"$0.00","cart_total_price_display":"$12.80","cart_gst_display":"$1.16","cart":[{"name":"Flat White","variant_name":"Extra Large","variant_desc":"","variant_image":"images\/coffee-flatwhite.png","options":[{"name":"size","value":"XLG","price":520},{"name":"Milk","value":"Full Cream","price":0},{"name":"Strength","value":"Full","price":0},{"name":"Decaf","value":"Normal","price":0},{"name":"Temp","value":"Normal","price":0},{"name":"Honey","value":"None","price":0},{"name":"Syrup","value":"None","price":0},{"name":"White Sugar","value":"0","price":0},{"name":"Raw Sugar","value":"0","price":0},{"name":"Equal Sugar","value":"0","price":0},{"name":"Extra shot","value":"0","price":0}],"unitprice":520,"price":520,"category":"Hot Drinks","quantity":1},{"name":"Smoothie","variant_name":"Regular","variant_desc":"","variant_image":"images\/smoothie.png","options":[{"name":"size","v...
# 6  {"cart_size":2,"cart_surcharge":0,"cart_total_price":1280,"cart_gst":116.36363636363636,"cart_surcharge_display":"$0.00","cart_total_price_display":"$12.80","cart_gst_display":"$1.16","cart":[{"name":"Flat White","variant_name":"Extra Large","variant_desc":"","variant_image":"images\/coffee-flatwhite.png","options":[{"name":"size","value":"XLG","price":520},{"name":"Milk","value":"Full Cream","price":0},{"name":"Strength","value":"Full","price":0},{"name":"Decaf","value":"Normal","price":0},{"name":"Temp","value":"Normal","price":0},{"name":"Honey","value":"None","price":0},{"name":"Syrup","value":"None","price":0},{"name":"White Sugar","value":"0","price":0},{"name":"Raw Sugar","value":"0","price":0},{"name":"Equal Sugar","value":"0","price":0},{"name":"Extra shot","value":"0","price":0}],"unitprice":520,"price":520,"category":"Hot Drinks","quantity":1},{"name":"Smoothie","variant_name":"Regular","variant_desc":"","variant_image":"images\/smoothie.png","options":[{"name":"size","v...
# 7  {"cart_size":2,"cart_surcharge":0,"cart_total_price":1280,"cart_gst":116.36363636363636,"cart_surcharge_display":"$0.00","cart_total_price_display":"$12.80","cart_gst_display":"$1.16","cart":[{"name":"Flat White","variant_name":"Extra Large","variant_desc":"","variant_image":"images\/coffee-flatwhite.png","options":[{"name":"size","value":"XLG","price":520},{"name":"Milk","value":"Full Cream","price":0},{"name":"Strength","value":"Full","price":0},{"name":"Decaf","value":"Normal","price":0},{"name":"Temp","value":"Normal","price":0},{"name":"Honey","value":"None","price":0},{"name":"Syrup","value":"None","price":0},{"name":"White Sugar","value":"0","price":0},{"name":"Raw Sugar","value":"0","price":0},{"name":"Equal Sugar","value":"0","price":0},{"name":"Extra shot","value":"0","price":0}],"unitprice":520,"price":520,"category":"Hot Drinks","quantity":1},{"name":"Smoothie","variant_name":"Regular","variant_desc":"","variant_image":"images\/smoothie.png","options":[{"name":"size","v...
# 8  {"cart_size":2,"cart_surcharge":0,"cart_total_price":1280,"cart_gst":116.36363636363636,"cart_surcharge_display":"$0.00","cart_total_price_display":"$12.80","cart_gst_display":"$1.16","cart":[{"name":"Flat White","variant_name":"Extra Large","variant_desc":"","variant_image":"images\/coffee-flatwhite.png","options":[{"name":"size","value":"XLG","price":520},{"name":"Milk","value":"Full Cream","price":0},{"name":"Strength","value":"Full","price":0},{"name":"Decaf","value":"Normal","price":0},{"name":"Temp","value":"Normal","price":0},{"name":"Honey","value":"None","price":0},{"name":"Syrup","value":"None","price":0},{"name":"White Sugar","value":"0","price":0},{"name":"Raw Sugar","value":"0","price":0},{"name":"Equal Sugar","value":"0","price":0},{"name":"Extra shot","value":"0","price":0}],"unitprice":520,"price":520,"category":"Hot Drinks","quantity":1},{"name":"Smoothie","variant_name":"Regular","variant_desc":"","variant_image":"images\/smoothie.png","options":[{"name":"size","v...
# 9  {"cart_size":2,"cart_surcharge":0,"cart_total_price":1280,"cart_gst":116.36363636363636,"cart_surcharge_display":"$0.00","cart_total_price_display":"$12.80","cart_gst_display":"$1.16","cart":[{"name":"Flat White","variant_name":"Extra Large","variant_desc":"","variant_image":"images\/coffee-flatwhite.png","options":[{"name":"size","value":"XLG","price":520},{"name":"Milk","value":"Full Cream","price":0},{"name":"Strength","value":"Full","price":0},{"name":"Decaf","value":"Normal","price":0},{"name":"Temp","value":"Normal","price":0},{"name":"Honey","value":"None","price":0},{"name":"Syrup","value":"None","price":0},{"name":"White Sugar","value":"0","price":0},{"name":"Raw Sugar","value":"0","price":0},{"name":"Equal Sugar","value":"0","price":0},{"name":"Extra shot","value":"0","price":0}],"unitprice":520,"price":520,"category":"Hot Drinks","quantity":1},{"name":"Smoothie","variant_name":"Regular","variant_desc":"","variant_image":"images\/smoothie.png","options":[{"name":"size","v...

# %%
df.count()
# Out:
# order_id        10
# customer_id     10
# ip_addr         10
# date_created    10
# date_paid       10
# total           10
# status          10
# items           10
# dtype: int64
